# %% [markdown]
# ## Predicting Nationality of Individuals Using their Names with ML
# + Steps
#     - a dataset of firstnames
#     - a dataset of lastnames

# %%
## Load EDA
import pandas as pd
import numpy as np

# %%
# Load ML Pkgs
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Load Dataset
df = pd.read_csv("Names_Dataset.csv")

# %%
df.shape
# Out:
# (3238, 3)

# %%
df.head()
# Out:
#    Unnamed: 0    names nationality
# 0           0  Gershon     yiddish
# 1           1    Lantz     yiddish
# 2           2    Zaide     yiddish
# 3           3   Zalman     yiddish
# 4           4   Zindel     yiddish

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'names', 'nationality'], dtype='object')

# %%
df['nationality'].unique()
# Out:
# array(['yiddish', 'gaelic', 'african', 'irish', 'hungarian', 'german',
#        'swedish', 'japanese', 'italian', 'american', 'hawaiian', 'greek',
#        'polynesian', 'scandinavian', 'spanish', 'celtic', 'old-english',
#        'korean', 'sanskrit', 'african-american', 'hebrew', 'norse',
#        'chinese', 'finnish', 'persian', 'scottish', 'slavic', 'english',
#        'old-norse', 'dutch', 'armenian', 'welsh', 'polish', 'teutonic',
#        'russian', 'egyptian', 'arabic', 'swahili', 'native-american',
#        'old-french', 'french', 'middle-english', 'latin', 'vietnamese',
#        'danish', 'hindi', 'old-german', 'turkish', 'indian',
#        'czechoslovakian'], dtype=object)

# %%
class_names = ['yiddish', 'gaelic', 'african', 'irish', 'hungarian', 'german',
       'swedish', 'japanese', 'italian', 'american', 'hawaiian', 'greek',
       'polynesian', 'scandinavian', 'spanish', 'celtic', 'old-english',
       'korean', 'sanskrit', 'african-american', 'hebrew', 'norse',
       'chinese', 'finnish', 'persian', 'scottish', 'slavic', 'english',
       'old-norse', 'dutch', 'armenian', 'welsh', 'polish', 'teutonic',
       'russian', 'egyptian', 'arabic', 'swahili', 'native-american',
       'old-french', 'french', 'middle-english', 'latin', 'vietnamese',
       'danish', 'hindi', 'old-german', 'turkish', 'indian',
       'czechoslovakian']

# %%
len(class_names)
# Out:
# 50

# %%
df.groupby('nationality')['names'].size()
# Out:
# nationality
# african             100
# african-american    100
# american            100
# arabic              100
# armenian             17
# celtic               62
# chinese             100
# czechoslovakian      38
# danish               11
# dutch                24
# egyptian             30
# english             100
# finnish              13
# french              100
# gaelic               87
# german              100
# greek               100
# hawaiian            100
# hebrew              100
# hindi               100
# hungarian            64
# indian               25
# irish               100
# italian             100
# japanese            100
# korean               16
# latin               100
# middle-english       45
# native-american     100
# norse                40
# old-english         100
# old-french           46
# old-german           40
# old-norse            28
# persian              55
# polish               48
# polynesian           15
# russian              85
# sanskrit             28
# scandinavian        100
# scottish             74
# slavic               79
# spanish             100
# swahili              16
# swedish              14
# teutonic             32
# turkish              52
# vietnamese           52
# welsh                91
# yiddish              11
# Name: names, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.groupby('nationality')['names'].size().plot(kind='bar',figsize=(20,10))

# %%
# Features
Xfeatures = df['names']
ylabels= df['nationality']

# %%
# Vectorize Features
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()
# Out:
# ['aaliyah',
#  'aari',
#  'aaron',
#  'aase',
#  'aba',
#  'aban',
#  'abbas',
#  'abbellonna',
#  'abbott',
#  'abby',
#  'abdiel',
#  'abdulaziz',
#  'abel',
#  'abelard',
#  'abeni',
#  'abeque',
#  'abey',
#  'abeytu',
#  'abhay',
#  'abhijit',
#  'abhorson',
#  'abia',
#  'abiba',
#  'abie',
#  'abigail',
#  'abijah',
#  'abira',
#  'abital',
#  'abmaba',
#  'abner',
#  'abra',
#  'abraham',
#  'abrahsa',
#  'abriana',
#  'abril',
#  'absolom',
#  'abtin',
#  'abuna',
#  'acacio',
#  'acantha',
#  'ace',
#  'achachak',
#  'achazia',
#  'achilles',
#  'achuta',
#  'ackley',
#  'acton',
#  'acura',
#  'ada',
#  'adahy',
#  'adalai',
#  'adalbert',
#  'adalgisa',
#  'adalgiso',
#  'adalia',
#  'adam',
#  'adamina',
#  'adan',
#  'adar',
#  'adara',
#  'adare',
#  'addai',
#  'addison',
#  'adelaide',
#  'adelbert',
#  'adelfried',
#  'adelino',
#  'adelmio',
#  'adelmo',
#  'adelpha',
#  'ademaro',
#  'adena',
#  'adeodatus',
#  'aderes',
#  'adger',
#  'adham',
#  'adia',
#  'adie',
#  'adin',
#  'aditya',
#  'adler',
#  'adley',
#  'admon',
#  'adney',
#  'adoette',
#  'adolfina',
#  'adolph',
#  'adon',
#  'adonis',
#  'adora',
#  'adrian',
#  'adrienne',
#  'adsila',
#  'aeary',
#  'aegle',
#  'aella',
#  'aemilia',
#  'aemilius',
#  'affera',
#  'affinity',
#  'afra',
#  'afram',
#  'afric',
#  'africa',
#  'afrodite',
#  'afton',
#  'agamemnon',
#  'agape',
#  'agapetus',
#  'agata',
#  'agatho',
#  'aglaia',
#  'agnes',
#  'agrippa',
#  'agrona',
#  'ah',
#  'ahab',
#  'ahanu',
#  'ahava',
#  'ahearn',
#  'ahmad',
#  'ahmik',
#  'ahmose',
#  'ahren',
#  'ahura',
#  'ai',
#  'aida',
#  'aidia',
#  'aiken',
#  'aiko',
#  'aileen',
#  'ailis',
#  'ailsa',
#  'aimee',
#  'aimon',
#  'ainsley',
#  'aisha',
#  'aislinn',
#  'aissa',
#  'aitan',
#  'aiyana',
#  'ajatashatru',
#  'ajax',
#  'ajay',
#  'ajua',
#  'akaash',
#  'akaisha',
#  'akako',
#  'akamu',
#  'akanah',
#  'akbar',
#  'akecheta',
#  'akelah',
#  'aki',
#  'akilah',
#  'akim',
#  'akina',
#  'akira',
#  'akiva',
#  'akiyama',
#  'akosua',
#  'aksel',
#  'akshay',
#  'akuti',
#  'al',
#  'alair',
#  'alam',
#  'alameda',
#  'alan',
#  'alana',
#  'alaqua',
#  'alaric',
#  'alastair',
#  'alawa',
#  'alba',
#  'alban',
#  'albert',
#  'alberta',
#  'albrecht',
#  'alcander',
#  'alcibiades',
#  'alcina',
#  'alcott',
#  'alden',
#  'alder',
#  'aldo',
#  'aldora',
#  'aldrich',
#  'aleron',
#  'aleshanee',
#  'alethea',
#  'alexander',
#  'alexandra',
#  'alexandrite',
#  'aleyn',
#  'alfonso',
#  'alford',
#  'alfred',
#  'alger',
#  'algernon',
#  'algoma',
#  'ali',
#  'alice',
#  'alida',
#  'alima',
#  'alisha',
#  'alison',
#  'alivia',
#  'alixia',
#  'aliye',
#  'aliza',
#  'alize',
#  'alka',
#  'allard',
#  'allaya',
#  'allegra',
#  'alleta',
#  'allston',
#  'alma',
#  'alo',
#  'aloani',
#  'aloha',
#  'alohi',
#  'alona',
#  'aloysia',
#  'aloysius',
#  'alphaeus',
#  'alphus',
#  'alsoomse',
#  'altair',
#  'althea',
#  'alton',
#  'aludra',
#  'alumit',
#  'alva',
#  'alvertos',
#  'alvin',
#  'alvina',
#  'alvis',
#  'alyssa',
#  'amadahy',
#  'amadeus',
#  'amal',
#  'amanda',
#  'amando',
#  'amar',
#  'amara',
#  'amarante',
#  'amari',
#  'amarie',
#  'amaris',
#  'amaros',
#  'amator',
#  'amaya',
#  'amber',
#  'ambrose',
#  'ambrosia',
#  'amedeo',
#  'amelia',
#  'amerie',
#  'amerigo',
#  'ames',
#  'amethyst',
#  'amherst',
#  'ami',
#  'amiable',
#  'amiel',
#  'amiens',
#  'amina',
#  'aminta',
#  'amir',
#  'amissa',
#  'amit',
#  'amitola',
#  'amity',
#  'amon',
#  'amory',
#  'amos',
#  'amour',
#  'amphitrite',
#  'amram',
#  'amriel',
#  'amund',
#  'amy',
#  'an',
#  'anaba',
#  'anacletus',
#  'analu',
#  'anan',
#  'anand',
#  'anani',
#  'ananias',
#  'anara',
#  'anastasia',
#  'anastasius',
#  'anath',
#  'anatole',
#  'anay',
#  'ancel',
#  'anderson',
#  'andrea',
#  'andrew',
#  'andromache',
#  'andromeda',
#  'aneesa',
#  'aneko',
#  'anezka',
#  'angel',
#  'angela',
#  'angeni',
#  'angus',
#  'anicetus',
#  'anisa',
#  'anita',
#  'anjali',
#  'anker',
#  'ankhhaf',
#  'ann',
#  'annabeth',
#  'annalynn',
#  'annan',
#  'annas',
#  'anneliese',
#  'anoop',
#  'anselm',
#  'anson',
#  'anstice',
#  'antenor',
#  'anthony',
#  'antigonus',
#  'antje',
#  'antlia',
#  'antonia',
#  'anuradha',
#  'anusha',
#  'anya',
#  'anysia',
#  'anzan',
#  'anzu',
#  'aoi',
#  'aparna',
#  'apenimon',
#  'aphrodite',
#  'apollo',
#  'aponi',
#  'apostolos',
#  'apphia',
#  'apple',
#  'april',
#  'apus',
#  'aqualina',
#  'aquamarine',
#  'aquarius',
#  'aquene',
#  'aquila',
#  'ara',
#  'arabelle',
#  'arali',
#  'araminta',
#  'aramis',
#  'arantxa',
#  'arash',
#  'arashel',
#  'arbor',
#  'arcadicus',
#  'archangelo',
#  'archelaus',
#  'archibald',
#  'archimedes',
#  'ardalan',
#  'arden',
#  'ardeshir',
#  'ardys',
#  'arel',
#  'arella',
#  'ares',
#  'aretha',
#  'aretino',
#  'argus',
#  'aria',
#  'ariadne',
#  'ariana',
#  'ariel',
#  'aries',
#  'aril',
#  'arion',
#  'arissa',
#  'aristide',
#  'aristotle',
#  'arjun',
#  'arland',
#  'arledge',
#  'arleigh',
#  'arlene',
#  'arley',
#  'arlo',
#  'armand',
#  'armani',
#  'armstrong',
#  'arnold',
#  'arnon',
#  'arrietty',
#  'arrigo',
#  'arsenio',
#  'arslan',
#  'artemia',
#  'artemis',
#  'arthur',
#  'artis',
#  'aruiragus',
#  'aruna',
#  'arundel',
#  'arva',
#  'arvid',
#  'arwen',
#  'arziki',
#  'asa',
#  'asad',
#  'ascah',
#  'aseem',
#  'asenath',
#  'asenka',
#  'asha',
#  'ashab',
#  'ashanti',
#  'asher',
#  'ashkii',
#  'ashland',
#  'ashley',
#  'asija',
#  'asisa',
#  'asmodel',
#  'aspen',
#  'asphar',
#  'aster',
#  'astin',
#  'astrid',
#  'asuman',
#  'asvin',
#  'atara',
#  'atash',
#  'athan',
#  'athanasios',
#  'atharvan',
#  'athelstan',
#  'athena',
#  'athol',
#  'athos',
#  'atilla',
#  'atlanta',
#  'atlas',
#  'atley',
#  'atohi',
#  'atropos',
#  'atticus',
#  'attilio',
#  'atul',
#  'atwell',
#  'aubrey',
#  'auburn',
#  'audie',
#  'audio',
#  'audrey',
#  'audric',
#  'august',
#  'augusta',
#  'aulii',
#  'aurelia',
#  'aureliano',
#  'aurelius',
#  'auriga',
#  'aurora',
#  'austin',
#  'autolocus',
#  'autumn',
#  'ava',
#  'avalon',
#  'avel',
#  'averill',
#  'avery',
#  'avicus',
#  'avis',
#  'aviva',
#  'avon',
#  'avonmore',
#  'avril',
#  'awarnach',
#  'awendela',
#  'axel',
#  'ayala',
#  'ayame',
#  'ayana',
#  'ayasha',
#  'ayers',
#  'ayita',
#  'ayla',
#  'aylin',
#  'ayn',
#  'azad',
#  'azalea',
#  'azar',
#  'azariah',
#  'azarin',
#  'azeem',
#  'azura',
#  'baako',
#  'babette',
#  'babyface',
#  'badal',
#  'baden',
#  'badr',
#  'bahram',
#  'bailey',
#  'bain',
#  'bairre',
#  'baker',
#  'bala',
#  'balaji',
#  'balavan',
#  'balder',
#  'baldev',
#  'baldwin',
#  'balin',
#  'ballard',
#  'ballentine',
#  'ballinamore',
#  'baltasar',
#  'bambi',
#  'banagher',
#  'bancroft',
#  'bane',
#  'banji',
#  'banjo',
#  'banke',
#  'bankei',
#  'banko',
#  'banu',
#  'banzan',
#  'bao',
#  'baptiste',
#  'bara',
#  'barbara',
#  'barbaras',
#  'barber',
#  'barclay',
#  'bardalph',
#  'barika',
#  'barker',
#  'barnabas',
#  'barnett',
#  'baron',
#  'barric',
#  'barry',
#  'bartholomew',
#  'bartram',
#  'baruch',
#  'basalt',
#  'basanti',
#  'basha',
#  'bashira',
#  'basil',
#  'basilissa',
#  'basim',
#  'basimah',
#  'bassett',
#  'bassui',
#  'bates',
#  'bathsheba',
#  'bayard',
#  'beacan',
#  'beacher',
#  'beardsley',
#  'beata',
#  'beatrice',
#  'beau',
#  'beck',
#  'becky',
#  'bede',
#  'bedegrayne',
#  'bedelia',
#  'bedrich',
#  'behdad',
#  'behruz',
#  'bela',
#  'beldon',
#  'belinda',
#  'bellamy',
#  'bellona',
#  'beltran',
#  'bemossed',
#  'bemus',
#  'bena',
#  'benaiah',
#  'benedetta',
#  'benedict',
#  'benen',
#  'benjamin',
#  'benjiro',
#  'bennett',
#  'benson',
#  'bentley',
#  'benvenuto',
#  'benvolio',
#  'bergen',
#  'berit',
#  'berk',
#  'berlynn',
#  'bernadette',
#  'bernard',
#  'bernstein',
#  'berto',
#  'bertram',
#  'beryl',
#  'bess',
#  'bethany',
#  'bettina',
#  'beulah',
#  'beverly',
#  'bevin',
#  'beyonce',
#  'bharat',
#  'bharati',
#  'bhudev',
#  'bhuma',
#  'bianca',
#  'bibi',
#  'bidziil',
#  'bijan',
#  'billie',
#  'bina',
#  'bindiya',
#  'bing',
#  'bingham',
#  'binney',
#  'biondello',
#  'birch',
#  'birdee',
#  'birgit',
#  'bisa',
#  'bishop',
#  'bjorn',
#  'blaan',
#  'blackburn',
#  'blade',
#  'blaine',
#  'blair',
#  'blaise',
#  'blake',
#  'blase',
#  'blaz',
#  'blaze',
#  'bliss',
#  'blossom',
#  'blue',
#  'bluma',
#  'bly',
#  'blythe',
#  'bo',
#  'boden',
#  'bogart',
#  'bohdana',
#  'bonar',
#  'boniface',
#  'bonnie',
#  'bono',
#  'booker',
#  'boone',
#  'booth',
#  'borachio',
#  'borak',
#  'borden',
#  'borg',
#  'boris',
#  'borna',
#  'boston',
#  'boswell',
#  'botan',
#  'boutros',
#  'bowen',
#  'boyce',
#  'boyd',
#  'braden',
#  'bradley',
#  'bram',
#  'bramha',
#  'bramwell',
#  'branch',
#  'brandeis',
#  'brandie',
#  'brandon',
#  'brant',
#  'braulio',
#  'brawley',
#  'brea',
#  'breck',
#  'breena',
#  'brena',
#  'brenda',
#  'brent',
#  'breri',
#  'brett',
#  'brewster',
#  'brian',
#  'briar',
#  'brice',
#  'bridget',
#  'brigham',
#  'brighton',
#  'brinley',
#  'brittany',
#  'brock',
#  'broderick',
#  'bromley',
#  'bronco',
#  'bronson',
#  'bronwen',
#  'bronze',
#  'brook',
#  'bruce',
#  'bruna',
#  'bryce',
#  'bryn',
#  'bryony',
#  'buckley',
#  'bud',
#  'buffy',
#  'bukka',
#  'burdette',
#  'burgess',
#  'burke',
#  'burle',
#  'burne',
#  'burr',
#  'butch',
#  'buzz',
#  'byrd',
#  'byron',
#  'cabal',
#  'cable',
#  'cacey',
#  'cade',
#  'cady',
#  'caedmon',
#  'caelan',
#  'caelum',
#  'caesar',
#  'cage',
#  'cahir',
#  'caithness',
#  'caitlin',
#  'caius',
#  'cajetan',
#  'cala',
#  'calcite',
#  'calder',
#  'calen',
#  'calendula',
#  'calhoun',
#  'callan',
#  'callis',
#  'callistus',
#  'calvin',
#  'cambria',
#  'camden',
#  'cameo',
#  'camera',
#  'cameron',
#  'camille',
#  'camillo',
#  'campbell',
#  'canaan',
#  'cancer',
#  'candida',
#  'candidius',
#  'candra',
#  'canice',
#  'canon',
#  'canute',
#  'caprice',
#  'capricornus',
#  'capucius',
#  'cara',
#  'carden',
#  'carew',
#  'carey',
#  'carin',
#  'carina',
#  'carisa',
#  'carl',
#  'carla',
#  'carlotta',
#  'carlow',
#  'carmelo',
#  'carmine',
#  'carnelian',
#  'carol',
#  'caroline',
#  'carolus',
#  'caron',
#  'carrick',
#  'carson',
#  'carsten',
#  'carvell',
#  'carys',
#  'casey',
#  'casimir',
#  'casmir',
#  'caspar',
#  'cassidy',
#  'cassietta',
#  'cassius',
#  'castor',
#  'catava',
#  'cato',
#  'cavalon',
#  'cavanaugh',
#  'ceara',
#  'cecania',
#  'cedar',
#  'cedric',
#  'celesto',
#  'centaurus',
#  'cepheus',
#  'cerek',
#  'ceridwen',
#  'cerise',
#  'cerny',
#  'cettina',
#  'cetus',
#  'chablis',
#  'chainey',
#  'chaka',
#  'chalee',
#  'chance',
#  'chancellor',
#  'chandra',
#  'chanel',
#  'channing',
#  'chantal',
#  'chao',
#  'chapa',
#  'charlotte',
#  'charon',
#  'charu',
#  'chase',
#  'chata',
#  'chatam',
#  'chatillon',
#  'chay',
#  'chelsea',
#  'chen',
#  'chenoa',
#  'cheriss',
#  'cheryl',
#  'chesmu',
#  'chester',
#  'cheveyo',
#  'chevy',
#  'cheyenne',
#  'chhaya',
#  'chiamaka',
#  'chika',
#  'chike',
#  'chimalis',
#  'chimon',
#  'chinshu',
#  'chio',
#  'chione',
#  'chipo',
#  'chitrangda',
#  'chivalry',
#  'chiyo',
#  'cho',
#  'chogan',
#  'chon',
#  'chorei',
#  'chotan',
#  'chow',
#  'christy',
#  'chu',
#  'chun',
#  'chung',
#  'churchill',
#  'chyou',
#  'ciannait',
#  'ciaran',
#  'ciel',
#  'cipriano',
#  'ciqala',
#  'circinus',
#  'cirrillo',
#  'cisco',
#  'citrine',
#  'clachas',
#  'clancy',
#  'claudette',
#  'clay',
#  'cleotha',
#  'clodagh',
#  'clovis',
#  'clyde',
#  'cochise',
#  'coco',
#  'cola',
#  'colar',
#  'colbert',
#  'colette',
#  'colin',
#  'colleen',
#  'colm',
#  'colville',
#  'coman',
#  'conall',
#  'conan',
#  'confucius',
#  'cong',
#  'conner',
#  'conrad',
#  'constanzo',
#  'contessa',
#  'conway',
#  'coolio',
#  'corbin',
#  'cordelia',
#  'corky',
#  'corliss',
#  'cormack',
#  'corrado',
#  'cortez',
#  'corvette',
#  'cotovatre',
#  'courage',
#  'courtesy',
#  'courtney',
#  'courvoisier',
#  'coyne',
#  'craig',
#  'cricket',
#  'crisiant',
#  'crockett',
#  'cruz',
#  'cuba',
#  'cullen',
#  'curan',
#  'curtis',
#  'cuyler',
#  'cydney',
#  'cyra',
#  'cyrus',
#  'cyzarine',
#  'da',
#  'dabney',
#  'dacian',
#  'daelen',
#  'daeshim',
#  'dag',
#  'dagmar',
#  'dagna',
#  'dagobert',
#  'dahlia',
#  'dai',
#  'daido',
#  'dailan',
#  'daire',
#  'dakarai',
#  'dakota',
#  'dalbert',
#  'dale',
#  'dallas',
#  'dallin',
#  'dame',
#  'damek',
#  'damita',
#  'dana',
#  'dannon',
#  'danuta',
#  'darby',
#  'darcie',
#  'darcy',
#  'dareh',
#  'darena',
#  'darice',
#  'dario',
#  'darius',
#  'darlene',
#  'darnell',
#  'darrell',
#  'darshana',
#  'darva',
#  'daryn',
#  'dashiell',
#  'dattatreya',
#  'davin',
#  'davine',
#  'davood',
#  'dawn',
#  'dax',
#  'day',
#  'deandre',
#  'debbani',
#  ...]

# %%
# Save Our Vectorizer
from sklearn.externals import joblib

# %%
nationality_vectorizer = open("nationality_vectorizer.pkl","wb")
joblib.dump(cv,nationality_vectorizer)

# %%
nationality_vectorizer.close()

# %%
# Split Dataset into Train/Test
x_train,x_test,y_train,y_test = train_test_split(X,ylabels,test_size=0.33,random_state=42)

# %%
## Build Model
nv = MultinomialNB()
nv.fit(x_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Accuracy of Our Model
nv.score(x_test,y_test)
# Out:
# 0.05986903648269411

# %%
sample1 = ["Kofi"]

# %%
vect1 = cv.transform(sample1).toarray()

# %%
nv.predict(vect1)
# Out:
# array(['african'], dtype='<U16')

# %%
sample2= ["Li","John","Ali","Vladmir"]

# %%
vect2 = cv.transform(sample2).toarray()

# %%
nv.predict(vect2)
# Out:
# array(['chinese', 'french', 'arabic', 'french'], dtype='<U16')

# %%
# Logistic Regression
logit = LogisticRegression()
logit.fit(x_train,y_train)
# Out:
# c:\users\thispc~1\virtua~1\jvirtu~1\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\thispc~1\virtua~1\jvirtu~1\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
logit.score(x_test,y_test)
# Out:
# 0.06548175865294668

# %%
# Single Prediction with Logit
logit.predict(vect1)
# Out:
# array(['african'], dtype=object)

# %%
# Multiple Prediction
logit.predict(vect2)
# Out:
# array(['chinese', 'french', 'arabic', 'french'], dtype=object)

# %%
sample_3 = ["katya","natasha"]

# %%
vect3 = cv.transform(sample_3).toarray()

# %%
logit.predict(vect3)
# Out:
# array(['french', 'french'], dtype=object)

# %%
# Interpretation of Model

# %%
import eli5

# %%
class_names
# Out:
# ['yiddish',
#  'gaelic',
#  'african',
#  'irish',
#  'hungarian',
#  'german',
#  'swedish',
#  'japanese',
#  'italian',
#  'american',
#  'hawaiian',
#  'greek',
#  'polynesian',
#  'scandinavian',
#  'spanish',
#  'celtic',
#  'old-english',
#  'korean',
#  'sanskrit',
#  'african-american',
#  'hebrew',
#  'norse',
#  'chinese',
#  'finnish',
#  'persian',
#  'scottish',
#  'slavic',
#  'english',
#  'old-norse',
#  'dutch',
#  'armenian',
#  'welsh',
#  'polish',
#  'teutonic',
#  'russian',
#  'egyptian',
#  'arabic',
#  'swahili',
#  'native-american',
#  'old-french',
#  'french',
#  'middle-english',
#  'latin',
#  'vietnamese',
#  'danish',
#  'hindi',
#  'old-german',
#  'turkish',
#  'indian',
#  'czechoslovakian']

# %%
# Show the weights
eli5.show_weights(logit,target_names=class_names )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=yiddish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=gaelic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=african
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=irish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hungarian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=german
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=swedish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=japanese
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=italian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=american
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hawaiian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=greek
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=polynesian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=scandinavian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=spanish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=celtic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=old-english
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=korean
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=sanskrit
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=african-american
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hebrew
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=norse
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=chinese
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=finnish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=persian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=scottish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=slavic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=english
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=old-norse
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=dutch
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=armenian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=welsh
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=polish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=teutonic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=russian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=egyptian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style

# %%
feature_names = cv.get_feature_names()

# %%
eli5.show_weights(logit,feature_names=feature_names,target_names=class_names )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=yiddish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=gaelic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=african
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=irish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hungarian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=german
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=swedish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=japanese
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=italian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=american
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hawaiian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=greek
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=polynesian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=scandinavian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=spanish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=celtic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=old-english
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=korean
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=sanskrit
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=african-american
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hebrew
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=norse
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=chinese
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=finnish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=persian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=scottish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=slavic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=english
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=old-norse
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=dutch
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=armenian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=welsh
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=polish
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=teutonic
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=russian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=egyptian
#
# </b>
#
# top features
#                     </td>
#
#                     <td style

# %%
# Single Pred Explanation
ex1 = np.reshape(vect1,-1,1)

# %%
eli5.show_prediction(logit,ex1,target_names=class_names,feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=yiddish
#
# </b>
#
#
#     (probability <b>0.067</b>, score <b>-2.535</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=gaelic
#
# </b>
#
#
#     (probability <b>0.029</b>, score <b>-3.420</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=african
#
# </b>
#
#
#     (probability <b>0.030</b>, score <b>-3.401</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=irish
#
# </b>
#
#
#     (probability <b>0.027</b>, score <b>-3.483</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hungarian
#
# </b>
#
#
#     (probability <b>0.007</b>, score <b>-4.807</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=german
#
# </b>
#
#
#     (probability <b>0.018</b>, score <b>-3.912</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=swedish
#
# </b>
#
#
#     (probability <b>0.028</b>, score <b>-3.440</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=japanese
#
# </b>
#
#
#     (probability <b>0.013</b>, score <b>-4.215</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=italian
#
# </b>
#
#
#     (probability <b>0.006</b>, score <b>-5.108</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=american
#
# </b>
#
#
#     (probability <b>0.009</b>, score <b>-4.616</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hawaiian
#
# </b>
#
#
#     (probability <b>0.011</b>, score <b>-4.375</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=greek
#
# </b>
#
#
#     (probability <b>0.030</b>, score <b>-3.389</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=polynesian
#
# </b>
#
#
#     (probability <b>0.006</b>, score <b>-5.040</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=scandinavian
#
# </b>
#
#
#     (probability <b>0.031</b>, score <b>-3.335</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=spanish
#
# </b>
#
#
#     (probability <b>0.024</b>, score <b>-3.608</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=celtic
#
# </b>
#
#
#     (probability <b>0.028</b>, score <b>-3.471</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=old-english
#
# </b>
#
#
#     (probability <b>0.030</b>, score <b>-3.379</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=korean
#
# </b>
#
#
#     (probability <b>0.026</b>, score <b>-3.522</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=sanskrit
#
# </b>
#
#
#     (probability <b>0.029</b>, score <b>-3.415</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=african-american
#
# </b>
#
#
#     (probability <b>0.027</b>, score <b>-3.495</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=hebrew
#
# </b>
#
#
#     (probability <b>0.019</b>, score <b>-3.864</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=norse
#
# </b>
#
#
#     (probability <b>0.009</b>, score <b>-4.656</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=chinese
#
# </b>
#
#
#     (probability <b>0.025</b>, score <b>-3.592</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=finnish
#
# </b>
#
#
#     (probability <b>0.030</b>, score <b>-3.397</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=persian
#
# </b>
#
#
#     (probability <b>0.026</b>, score <b>-3.514</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=scottish
#
# </b>
#
#
#     (probability <b>0.007</b>, score <b>-4.920</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=slavic
#
# </b>
#
#
#     (probability <b>0.029</b>, score <b>-3.432</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=english
#
# </b>
#
#
#     (probability <b>0.014</b>, score <b>-4.157</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">

# %%
# Save Our Model
from sklearn.externals import joblib

# %%
nationality_nv_model = open("nationality_nv_model.pkl","wb")
joblib.dump(nv,nationality_nv_model)

# %%
nationality_nv_model.close()

# %%
nationality_logit_model = open("nationality_logit_model.pkl","wb")
joblib.dump(nv,nationality_logit_model)

# %%
nationality_logit_model.close()
